# %%
import pandas as pd

train_data_path = "/Users/shakedcaspi/Documents/tau/deep_learning_workshop/Deep-Learning-Workshop/data/higgs/raw_data/training.csv"
data = pd.read_csv(train_data_path)

data
# Out:
#         EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 0        100000       138.470                       51.655        97.827
# 1        100001       160.937                       68.768       103.235
# 2        100002      -999.000                      162.172       125.953
# 3        100003       143.905                       81.417        80.943
# 4        100004       175.864                       16.915       134.805
# ...         ...           ...                          ...           ...
# 249995   349995      -999.000                       71.989        36.548
# 249996   349996      -999.000                       58.179        68.083
# 249997   349997       105.457                       60.526        75.839
# 249998   349998        94.951                       19.362        68.812
# 249999   349999      -999.000                       72.756        70.831
#
#         DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# ...

# %%
data.shape
# Out:
# (250000, 33)

# %%
data.index.to_list()[:2]
# Out:
# [0, 1]

# %%
data.iloc[data.index.to_list()[:2]].values.shape
# Out:
# (2, 30)

# %%
lst = data.columns.drop(["EventId", "Weight","Label"])

# %%
lst
# Out:
# Index(['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis',
#        'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet',
#        'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt',
#        'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality',
#        'DER_lep_eta_centrality', 'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi',
#        'PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi',
#        'PRI_met_sumet', 'PRI_jet_num', 'PRI_jet_leading_pt',
#        'PRI_jet_leading_eta', 'PRI_jet_leading_phi', 'PRI_jet_subleading_pt',
#        'PRI_jet_subleading_eta', 'PRI_jet_subleading_phi', 'PRI_jet_all_pt'],
#       dtype='object')

# %%
CLASS_NAMES = ["s", "b"]
rename_cls_labels = {
    c: f"data.cls_labels.{c}" for c in CLASS_NAMES}

# %%
rename_cls_labels
# Out:
# {'s': 'data.cls_labels.s', 'b': 'data.cls_labels.b'}

# %%
data.isna().sum(axis=0)
# Out:
# EventId                        0
# DER_mass_MMC                   0
# DER_mass_transverse_met_lep    0
# DER_mass_vis                   0
# DER_pt_h                       0
# DER_deltaeta_jet_jet           0
# DER_mass_jet_jet               0
# DER_prodeta_jet_jet            0
# DER_deltar_tau_lep             0
# DER_pt_tot                     0
# DER_sum_pt                     0
# DER_pt_ratio_lep_tau           0
# DER_met_phi_centrality         0
# DER_lep_eta_centrality         0
# PRI_tau_pt                     0
# PRI_tau_eta                    0
# PRI_tau_phi                    0
# PRI_lep_pt                     0
# PRI_lep_eta                    0
# PRI_lep_phi                    0
# PRI_met                        0
# PRI_met_phi                    0
# PRI_met_sumet                  0
# PRI_jet_num                    0
# PRI_jet_leading_pt             0
# PRI_jet_leading_eta            0
# PRI_jet_leading_phi            0
# PRI_jet_subleading_pt          0
# ...

# %%
data.head(1)
# Out:
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100000        138.47                       51.655        97.827     27.98
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
#
#    DER_deltar_tau_lep  DER_pt_tot  ...  PRI_jet_num  PRI_jet_leading_pt  \
# 0               3.064      41.928  ...            2              67.435
#
#    PRI_jet_leading_eta  PRI_jet_leading_phi  PRI_jet_subleading_pt  \
# 0                 2.15                0.444                 46.062
#
#    PRI_jet_subleading_eta  PRI_jet_subleading_phi  PRI_jet_all_pt    Weight  \
# 0                    1.24                  -2.475         113.497  0.002653
#
#    Label
# 0      s
#
# [1 rows x 33 columns]

# %%
data.drop("DER_mass_MMC", axis=1)
# Out:
#         EventId  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0        100000                       51.655        97.827    27.980
# 1        100001                       68.768       103.235    48.146
# 2        100002                      162.172       125.953    35.635
# 3        100003                       81.417        80.943     0.414
# 4        100004                       16.915       134.805    16.405
# ...         ...                          ...           ...       ...
# 249995   349995                       71.989        36.548     5.042
# 249996   349996                       58.179        68.083    22.439
# 249997   349997                       60.526        75.839    39.757
# 249998   349998                       19.362        68.812    13.504
# 249999   349999                       72.756        70.831     7.479
#
#         DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                       0.91           124.711                2.666
# ...
