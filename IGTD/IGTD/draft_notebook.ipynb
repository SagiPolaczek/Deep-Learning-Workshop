# %%
from scipy.stats import spearmanr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import shutil
from scipy.stats import rankdata
import time
from scipy.spatial.distance import pdist, squareform
import _pickle as cp

# %%
a = np.random.rand(10,10)

# %%
corr = np.corrcoef(np.transpose(a))
corr = 1 - corr
corr = np.around(a=corr, decimals=10)

# %%
num_r = num_c = 10
num = num_r
tril_id = np.tril_indices(num, k=-1)
rank = rankdata(corr[tril_id])
feature_ranking = np.zeros((num,num))
feature_ranking[tril_id] = rank
feature_ranking = feature_ranking + feature_ranking.T

# %%
for r in range(num_r):
    if r == 0:
        coordinate = np.transpose(np.vstack((np.zeros(num_c), range(num_c))))
    else:
        coordinate = np.vstack((coordinate, np.transpose(np.vstack((np.ones(num_c) * r, range(num_c))))))

# %%
num = num_r * num_c
cord_dist = np.zeros((num, num))    
for i in range(num_r):
    cord_dist[i, :] = np.sqrt(np.square(coordinate[i, 0] * np.ones(num) - coordinate[:, 0]) + \
         np.square(coordinate[i, 1] * np.ones(num) - coordinate[:, 1]))

# %%
tril_id = np.tril_indices(num, k=-1)
rank = rankdata(cord_dist[tril_id])
coor_ranking = np.zeros((num, num))
coor_ranking[tril_id] = rank
coor_ranking = coor_ranking + np.transpose(coor_ranking)
coordinate = np.int64(coordinate)

# %%
generate_coor_matrix = (coordinate[:, 0], coordinate[:, 1]), coor_ranking

# %%
max_step = 1000

# %%
source = feature_ranking.copy()
num = source.shape[0]
tril_id = np.array(range(num))
index = np.array(range(num))
index_record = np.empty((max_step + 1, num))
index_record.fill(np.nan)
index_record[0, :] = index.copy()

# %%
feature_ranking
# Out:
# array([[ 0., 29., 18., 40., 32., 45., 12., 23., 39., 21.],
#        [29.,  0., 17., 13., 36.,  2., 20.,  3.,  9., 31.],
#        [18., 17.,  0., 43., 41., 28.,  1., 26., 10., 37.],
#        [40., 13., 43.,  0.,  8.,  5., 42.,  6., 15., 22.],
#        [32., 36., 41.,  8.,  0., 27., 44., 25., 34., 19.],
#        [45.,  2., 28.,  5., 27.,  0., 38.,  7.,  4., 14.],
#        [12., 20.,  1., 42., 44., 38.,  0., 30., 11., 24.],
#        [23.,  3., 26.,  6., 25.,  7., 30.,  0., 35., 16.],
#        [39.,  9., 10., 15., 34.,  4., 11., 35.,  0., 33.],
#        [21., 31., 37., 22., 19., 14., 24., 16., 33.,  0.]])

# %%
coor_ranking.shape
# Out:
# (100, 100)

# %%
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# '/Users/shakedcaspi/Documents/tau/deep_learning_workshop/Deep-Learning-Workshop/IGTD/IGTD'

# %%
df = pd.read_csv("/Users/shakedcaspi/Documents/tau/deep_learning_workshop/Deep-Learning-Workshop/Data/Data.txt", 
                sep="\t", 
                )
df.shape

# %%
# Out:
# (100, 1601)

# %%
df
# Out:
#    Unnamed: 0       A2M     A2ML1      AARD     ABCA3     ABCC3       ABO  \
# 0     CCL_100  0.000000  0.004091  0.000000  0.561184  0.809589  0.508927
# 1    CCL_1000  0.006729  0.031288  0.159117  0.807279  0.362367  0.011058
# 2    CCL_1001  0.003595  0.014950  0.000000  0.035164  0.720730  0.544742
# 3    CCL_1002  0.054388  0.000000  0.007907  0.065095  0.819842  0.000000
# 4    CCL_1003  0.017330  0.000000  0.364831  0.016931  0.074374  0.000000
# ..        ...       ...       ...       ...       ...       ...       ...
# 95    CCL_127  0.670907  0.004091  0.022737  0.131477  0.022882  0.000000
# 96    CCL_129  0.009495  0.008155  0.003960  0.356638  0.026300  0.000000
# 97    CCL_130  0.086928  0.062531  0.057370  0.857617  0.041158  0.000000
# 98    CCL_131  0.010417  0.001352  0.188761  0.178299  0.728217  0.028965
# 99    CCL_132  0.009495  0.008155  0.214646  0.681036  0.864922  0.668784
#
#         ACP5      ACPP     ACSL5  ...     ZBED2   ZC3H12A   ZCCHC12     ZFP36  \
# 0   0.013216  0.000000  0.851887  ...  0.318390  0.552810  0.000000  0.675678
# 1   0.075197  0.065874  0.018458  ...  0.001046  0.381541  0.008078  0.453958
# 2   0.028788  0.144791  0.835093  ...  0.309043  0.468629  0.052602  0.556191
# 3   0.013216  0.025979  0.435861  ...  0.012383  0.428658  0.000000  0.424248
# 4   0.309702  0.000000  0.499200  ...  0.110159  0.391473  0.000000  0.375807
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 95  0.629136  0.057542  0.009165  ...  0.028828  0.250000  0.009420  0.496217
# 96  0.165045  0.385075  0.542067  ...  0.016501  0.381541  0.008078  0.443901
# 97  0.065977  0.006496  0.033429  ...  0.006191  0.030011  0.703892  0.415944
# 98  0.148448  0.006496  0.344850  ...  0.135980  0.834545  0.028295  0.200591
# 99  0.595328  0.000931  0.017274  ...  0.504595  0.391473  0.000000  0.268777
#
#        ZG16B      ZIC2   ZMYND10    ZNF703    ZNF750    ZNF853
# 0   0.895415  0.314206  0.035027  0.679502  0.011548  0.006667
# 1   0.672979  0.252963  0.488698  0.618830  0.428559  0.172000
# 2   0.123421  0.491748  0.049036  0.693784  0.037850  0.009833
# 3   0.064547  0.425185  0.325729  0.484461  0.006622  0.457833
# 4   0.004306  0.014055  0.162840  0.013368  0.102222  0.261167
# ..       ...       ...       ...       ...       ...       ...
# 95  0.008622  0.319278  0.136578  0.304616  0.024712  0.006667
# 96  0.113320  0.280924  0.250326  0.124771  0.029683  0.071167
# 97  0.035875  0.726573  0.539369  0.940585  0.009924  0.694167
# 98  0.060262  0.008945  0.105080  0.429159  0.011548  0.092500
# 99  0.130563  0.289956  0.276588  0.226005  0.052692  0.006667
#
# [100 rows x 1601 columns]
